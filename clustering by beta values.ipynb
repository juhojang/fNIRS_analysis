# %% [markdown]
# # 파일 불러오기

# %%
import pandas as pd


resultRP=pd.read_csv("C:/OBELAB/NIRSITLite_Setup/total result of 2nd level data(rest-play)(A-B)/1st level data/cB.csv")
resultRP.fillna(resultRP.mean(),inplace=True)
resultRS=pd.read_csv("C:/OBELAB/NIRSITLite_Setup/total result of 2nd level data(rest-see)(A-B)/1st level data/cB.csv")
resultRS.fillna(resultRS.mean(),inplace=True)
resultSP=pd.read_csv("C:/OBELAB/NIRSITLite_Setup/total result of 2nd level data(see-play)(A-B)/1st level data/cB.csv")
resultSP.fillna(resultSP.mean(),inplace=True)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8960\524661253.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   resultRP.fillna(resultRP.mean(),inplace=True)
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8960\524661253.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   resultRS.fillna(resultRS.mean(),inplace=True)
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8960\524661253.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   resultSP.fillna(resultSP.mean(),inplace=True)

# %% [markdown]
# # 상관관계 분석 및 탐색 채널 선택

# %%
import numpy as np
import seaborn as sns

df_rsA = resultRS[0:27].corr()
df_rsB = resultRS[27:54].corr()
df_rsC = resultRS[54:81].corr()
df_rpA=resultRP[0:27].corr()
df_rpB=resultRP[27:54].corr()
df_rpC=resultRP[54:81].corr()
df_spA=resultSP[0:27].corr()
df_spB=resultSP[27:54].corr()
df_spC=resultSP[54:81].corr()
sns.clustermap(df_rsA, 
               annot = True,      
               cmap = 'RdYlBu_r',  
               vmin = -1, vmax = 1, 
              )

# %%
sns.clustermap(df_rsB, 
               annot = True,    
               cmap = 'RdYlBu_r', 
               vmin = -1, vmax = 1,
              )

# %%
sns.clustermap(df_rsC, 
               annot = True,     
               cmap = 'RdYlBu_r', 
               vmin = -1, vmax = 1,
              )
cL=['Ch01','Ch02','Ch05','Ch06','Ch08','Ch14','Ch15']
i=0
for chA in range(len(cL)):
    for chB in range(chA,len(cL)):
        if df_rsC[cL[chA]][cL[chB]]>0.5 and chA!=chB:
            print(cL[chA], cL[chB])
# Out:
# Ch01 Ch05
# Ch01 Ch14
# Ch01 Ch15
# Ch05 Ch06
# Ch05 Ch08
# Ch05 Ch14
# Ch06 Ch08

# %%
sns.clustermap(df_rpA, 
               annot = True,   
               cmap = 'RdYlBu_r',  
               vmin = -1, vmax = 1, 
              )

# %%
sns.clustermap(df_rpB, 
               annot = True,     
               cmap = 'RdYlBu_r',  
               vmin = -1, vmax = 1,
              )

# %%
sns.clustermap(df_rpC, 
               annot = True,     
               cmap = 'RdYlBu_r',
               vmin = -1, vmax = 1,
              )

cL=['Ch03','Ch05','Ch06','Ch08','Ch09','Ch10']
for chA in range(len(cL)):
    for chB in range(chA,len(cL)):
        if df_rsC[cL[chA]][cL[chB]]>0.7 and chA!=chB:
            print(cL[chA], cL[chB])
# Out:
# Ch03 Ch06
# Ch03 Ch08
# Ch03 Ch09
# Ch06 Ch08
# Ch06 Ch09
# Ch08 Ch09

# %%
sns.clustermap(df_spA, 
               annot = True,     
               cmap = 'RdYlBu_r',  
               vmin = -1, vmax = 1, 
              )
cL=['Ch06','Ch08','Ch10','Ch11']
i=0
for chA in range(len(cL)):
    for chB in range(chA,len(cL)):
        if df_rsC[cL[chA]][cL[chB]]>0.7 and chA!=chB:
            print(cL[chA], cL[chB])
# Out:
# Ch06 Ch08
# Ch10 Ch11

# %%
import seaborn as sns

sns.clustermap(df_spB, 
               annot = True, 
               cmap = 'RdYlBu_r', 
               vmin = -1, vmax = 1,
              )

cL=['Ch06','Ch08','Ch09','Ch10']

for chA in range(len(cL)):
    for chB in range(chA,len(cL)):
        if df_rsC[cL[chA]][cL[chB]]>0.7 and chA!=chB:
            print(cL[chA], cL[chB])
# Out:
# Ch06 Ch08
# Ch06 Ch09
# Ch08 Ch09

# %%
sns.clustermap(df_spC, 
               annot = True,     
               cmap = 'RdYlBu_r', 
               vmin = -1, vmax = 1, 
              )

# %%
sns.clustermap(df_rpC, 
               annot = True,     
               cmap = 'RdYlBu_r', 
               vmin = -1, vmax = 1, 
              )

# %%
survey=pd.read_csv("C:/OBELAB/NIRSITLite_Setup/total result of 2nd level data(rest-play)(A-B)/Virtual-Pianist_self-report_dataset.csv")
survey.fillna(survey.mean(),inplace=True)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8960\1663224659.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   survey.fillna(survey.mean(),inplace=True)

# %%
survey
# Out:
#    subjectkey    date sex  age right_handed  piano_year  piano_major  \
# 0           1  230220   F   40            Y          10            1
# 1           2  230220   F   58            Y          50            1
# 2           3  230220   F   32            Y          25            1
# 3           4  230220   F   25            Y          10            1
# 4           5  230220   F   20            N          15            1
# 5           6  230220   F   40            Y          18            1
# 6           8  230220   M   45            Y          10            3
# 7           7  230220   F   51            Y           4            3
# 8           9  230220   F   21            Y           3            3
# 9          10  230220   F   28            Y          16            1
# 10         11  230220   F   32            Y           5            1
# 11         12  230221   M   26            Y          20            1
# 12         13  230221   F   41            Y          35            1
# ...

# %% [markdown]
# # RSC 분석

# %%
rsC = resultRS[54:81]
rsC.reset_index(inplace=True)

# %%
rsC=pd.concat([survey,rsC],axis=1)

# %%
from sklearn.preprocessing import StandardScaler

rsC_new=pd.DataFrame()
rsC_new['M1514']=(rsC['Ch01']+rsC['Ch05']+rsC['Ch14'])/3
rsC_new['M568']=(rsC['Ch05']+rsC['Ch06']+rsC['Ch08'])/3
rsC_new['M115']=(rsC['Ch01']+rsC['Ch15'])/2

sc=StandardScaler()
rsC_new_scaled=sc.fit_transform(rsC_new)
pd.DataFrame(rsC_new_scaled).head()
# Out:
#           0         1         2
# 0  0.124611 -0.080822 -0.035093
# 1  0.792509  1.635892  0.615850
# 2  0.189291  0.734952 -0.474314
# 3  1.323496 -0.174766  2.485747
# 4  0.387689  0.902100 -0.170123

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

inertia=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,random_state=0)
    clusters=kmeans.fit(rsC_new_scaled)
    inertia.append(kmeans.inertia_)
    
plt.plot(range(1,11),inertia,marker='o')
# Out:
# c:\Users\bml05\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kmeans=KMeans(n_clusters=3,random_state=0)
clusters=kmeans.fit(rsC_new_scaled)
rsC_new['clusters']=clusters.labels_

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(rsC_new['M568'],rsC_new['M1514'],c=rsC_new['clusters'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(rsC_new['M115'],rsC_new['M568'],c=rsC_new['clusters'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(rsC_new['M115'],rsC_new['M568'],c=rsC['piano_major'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(rsC_new['M115'],rsC_new['M1514'],c=rsC_new['clusters'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(rsC_new['M115'],rsC_new['M1514'],c=rsC['age'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(rsC_new['M568'],rsC_new['M115'],c=rsC_new['clusters'], s=50,cmap='gray')

# %% [markdown]
# # RPC 분석

# %%
rpC = resultRS[54:81]
rpC.reset_index(inplace=True)
rpC_new=pd.DataFrame()
rpC_new['M35689']=(rpC['Ch03']+rpC['Ch06']+rpC['Ch08']+rpC['Ch09'])/4
rpC_new['Ch05']=rpC['Ch05']
rpC_new['Ch10']=rpC['Ch10']

# %%
sc=StandardScaler()
rpC_new_scaled=sc.fit_transform(rpC_new)
pd.DataFrame(rpC_new_scaled).head()
# Out:
#           0         1         2
# 0 -0.529602  0.453271 -2.170964
# 1  1.669453  1.107149  0.136403
# 2  0.971655 -0.047080  1.585405
# 3 -0.920656  1.068356 -0.173108
# 4  1.059973  0.575085  0.935650

# %%
inertia=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,random_state=0)
    clusters=kmeans.fit(rpC_new_scaled)
    inertia.append(kmeans.inertia_)
    
plt.plot(range(1,11),inertia,marker='o')
# Out:
# c:\Users\bml05\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kmeans=KMeans(n_clusters=3,random_state=0)
clusters=kmeans.fit(rpC_new_scaled)
rpC_new['clusters']=clusters.labels_

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(rpC_new['M35689'],rpC_new['Ch05'],c=rpC_new['clusters'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(rpC_new['M35689'],rpC_new['Ch10'],c=rpC_new['clusters'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(rpC_new['M35689'],rpC_new['Ch10'],c=rsC['piano_major'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(rpC_new['M35689'],rpC_new['Ch10'],c=rsC['piano_year'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(rpC_new['Ch10'],rpC_new['Ch05'],c=rpC_new['clusters'], s=50,cmap='gray')

# %% [markdown]
# # SPA 분석

# %%
spA = resultSP[0:27]
spA.reset_index(inplace=True)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
spA_new=pd.DataFrame()
spA_new['M1011']=(spA['Ch10']+spA['Ch11'])/2
spA_new['M68']=(spA['Ch06']+spA['Ch08'])/2

sc=StandardScaler()
spA_new_scaled=sc.fit_transform(spA_new)
pd.DataFrame(spA_new_scaled).head()
# Out:
#           0         1
# 0  0.463718 -0.440293
# 1 -0.194550  0.006505
# 2  0.574291  1.014582
# 3 -0.084995  0.501622
# 4 -1.003241  0.176381

# %%
inertia=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,random_state=0)
    clusters=kmeans.fit(spA_new_scaled)
    inertia.append(kmeans.inertia_)
    
plt.plot(range(1,11),inertia,marker='o')
# Out:
# c:\Users\bml05\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kmeans=KMeans(n_clusters=4,random_state=0)
clusters=kmeans.fit(spA_new_scaled)
spA_new['clusters']=clusters.labels_

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(spA_new['M1011'],spA_new['M68'],c=spA_new['clusters'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(spA_new['M1011'],spA_new['M68'],c=rsC['piano_year'], s=50,cmap='gray')

# %% [markdown]
# # SPB 분석

# %%
spB = resultSP[27:54]
spB.reset_index(inplace=True)

# %%
spB_new=pd.DataFrame()
spB_new['M689']=(spB['Ch06']+spB['Ch08']+spB['Ch09'])/3
spB_new['Ch10']=spB['Ch10']

sc=StandardScaler()
spB_new_scaled=sc.fit_transform(spB_new)
pd.DataFrame(spB_new_scaled).head()
# Out:
#           0         1
# 0 -1.599701 -1.401142
# 1  0.603351  1.221851
# 2  0.748204  0.944671
# 3 -1.183364 -0.336982
# 4  1.887130  1.026259

# %%
inertia=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,random_state=0)
    clusters=kmeans.fit(spB_new_scaled)
    inertia.append(kmeans.inertia_)
    
plt.plot(range(1,11),inertia,marker='o')
# Out:
# c:\Users\bml05\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kmeans=KMeans(n_clusters=3,random_state=0)
clusters=kmeans.fit(spB_new_scaled)
spB_new['clusters']=clusters.labels_

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(spB_new['M689'],spB_new['Ch10'],c=spB_new['clusters'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(spB_new['M689'],spB_new['Ch10'],c=rsC['piano_year'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(spB_new['M689'],spB_new['Ch10'],c=rsC['impro_experience'], s=50,cmap='gray')

# %%
plt.figure(figsize=(10, 10))
ax = plt.gca()
ax.set_facecolor('m')
plt.scatter(spB_new['M689'],spB_new['Ch10'],c=rsC['pre_SE_08'], s=50,cmap='gray')
