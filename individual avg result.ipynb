# %%
import pandas as pd

result=pd.read_csv("D:\Dataset\play_dataset.csv")
result.dropna()
# Out:
#        name task  channel       avg         slope      variance  skewness  \
# 0    name_1    A        1  0.000515 -5.193940e-07  9.857140e-07 -0.149703
# 1    name_1    A        2 -0.000307 -3.447420e-06  2.065070e-06 -0.462305
# 2    name_1    A        3  0.000860  1.828470e-06  7.518800e-07  1.239883
# 3    name_1    A        4  0.001451 -5.648960e-07  3.208210e-06 -0.157429
# 4    name_1    A        5 -0.001106 -3.562820e-06  1.862200e-06 -0.260633
# ..      ...  ...      ...       ...           ...           ...       ...
# 850      k1    C       11  0.000914  9.693870e-08  1.938430e-07 -0.224819
# 851      k1    C       12  0.000185 -2.359430e-06  2.140740e-07  0.633481
# 852      k1    C       13  0.000801 -2.869640e-06  4.860280e-07 -0.376340
# 853      k1    C       14 -0.000063 -1.987430e-06  1.322780e-07 -0.368822
# 854      k1    C       15  0.001296 -3.912320e-07  3.409900e-07 -0.785307
#
#      kurtosis       max       min       sum
# ...

# %%
name_1_result=[]
task=['A','B','C']
result_1=result[result['name']=='name_1']
for i in task:
    save=[]
    result_1_A=result_1[result['task']==i]
    for j in range(1,16):
        save.append(result_1_A[result['channel']==j]['avg'].values[0])
    name_1_result.append(save)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\400088043.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_1_A=result_1[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\400088043.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_1_A[result['channel']==j]['avg'].values[0])

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_1 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_1_result[0][i-1], name_1_result[1][i-1],name_1_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)

# %%
name_2_result=[]
task=['A','B','C']
result_2=result[result['name']=='name_2']
for i in task:
    save=[]
    result_2_A=result_2[result['task']==i]
    for j in range(1,16):
        save.append(result_2_A[result['channel']==j]['avg'].values[0])
    name_2_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_2 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_2_result[0][i-1], name_2_result[1][i-1],name_2_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\1588722533.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_2_A=result_2[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\1588722533.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_2_A[result['channel']==j]['avg'].values[0])

# %%
name_3_result=[]
task=['A','B','C']
result_3=result[result['name']=='name_3']
for i in task:
    save=[]
    result_3_A=result_3[result['task']==i]
    for j in range(1,16):
        save.append(result_3_A[result['channel']==j]['avg'].values[0])
    name_3_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_3 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_3_result[0][i-1], name_3_result[1][i-1],name_3_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\4230471291.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_3_A=result_3[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\4230471291.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_3_A[result['channel']==j]['avg'].values[0])

# %%
name_4_result=[]
task=['A','B','C']
result_4=result[result['name']=='name_4']
for i in task:
    save=[]
    result_4_A=result_4[result['task']==i]
    for j in range(1,16):
        save.append(result_4_A[result['channel']==j]['avg'].values[0])
    name_4_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_4 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_4_result[0][i-1], name_4_result[1][i-1],name_4_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\4031248836.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_4_A=result_4[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\4031248836.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_4_A[result['channel']==j]['avg'].values[0])

# %%
name_5_result=[]
task=['A','B','C']
result_5=result[result['name']=='name_5']
for i in task:
    save=[]
    result_5_A=result_5[result['task']==i]
    for j in range(1,16):
        save.append(result_5_A[result['channel']==j]['avg'].values[0])
    name_5_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_5 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_5_result[0][i-1], name_5_result[1][i-1],name_5_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\3553167694.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_5_A=result_5[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\3553167694.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_5_A[result['channel']==j]['avg'].values[0])

# %%
name_6_result=[]
task=['A','B','C']
result_6=result[result['name']=='name_6']
for i in task:
    save=[]
    result_6_A=result_6[result['task']==i]
    for j in range(1,16):
        save.append(result_6_A[result['channel']==j]['avg'].values[0])
    name_6_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_6 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_6_result[0][i-1], name_6_result[1][i-1],name_6_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\2969227410.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_6_A=result_6[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\2969227410.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_6_A[result['channel']==j]['avg'].values[0])

# %%
name_7_result=[]
task=['A','B','C']
result_7=result[result['name']=='name_7']
for i in task:
    save=[]
    result_7_A=result_3[result['task']==i]
    for j in range(1,16):
        save.append(result_7_A[result['channel']==j]['avg'].values[0])
    name_7_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_7 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_7_result[0][i-1], name_7_result[1][i-1],name_7_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\2077641889.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_7_A=result_3[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\2077641889.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_7_A[result['channel']==j]['avg'].values[0])

# %%
name_8_result=[]
task=['A','B','C']
result_8=result[result['name']=='name_8']
for i in task:
    save=[]
    result_8_A=result_8[result['task']==i]
    for j in range(1,16):
        save.append(result_8_A[result['channel']==j]['avg'].values[0])
    name_8_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_8 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_8_result[0][i-1], name_8_result[1][i-1],name_8_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\3411254413.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_8_A=result_8[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\3411254413.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_8_A[result['channel']==j]['avg'].values[0])

# %%
name_9_result=[]
task=['A','B','C']
result_9=result[result['name']=='name_9']
for i in task:
    save=[]
    result_9_A=result_9[result['task']==i]
    for j in range(1,16):
        save.append(result_9_A[result['channel']==j]['avg'].values[0])
    name_9_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_9 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_9_result[0][i-1], name_9_result[1][i-1],name_9_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\826306786.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_9_A=result_9[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\826306786.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_9_A[result['channel']==j]['avg'].values[0])

# %%
name_10_result=[]
task=['A','B','C']
result_10=result[result['name']=='name_10']
for i in task:
    save=[]
    result_10_A=result_8[result['task']==i]
    for j in range(1,16):
        save.append(result_10_A[result['channel']==j]['avg'].values[0])
    name_10_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_10 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_10_result[0][i-1], name_10_result[1][i-1],name_10_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\1157035083.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_10_A=result_8[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\1157035083.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_10_A[result['channel']==j]['avg'].values[0])

# %%
name_11_result=[]
task=['A','B','C']
result_11=result[result['name']=='name_11']
for i in task:
    save=[]
    result_11_A=result_11[result['task']==i]
    for j in range(1,16):
        save.append(result_11_A[result['channel']==j]['avg'].values[0])
    name_11_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_11 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_11_result[0][i-1], name_11_result[1][i-1],name_11_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\2164171057.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_11_A=result_11[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\2164171057.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_11_A[result['channel']==j]['avg'].values[0])

# %%
name_12_result=[]
task=['A','B','C']
result_12=result[result['name']=='name_8']
for i in task:
    save=[]
    result_12_A=result_12[result['task']==i]
    for j in range(1,16):
        save.append(result_12_A[result['channel']==j]['avg'].values[0])
    name_12_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_12 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_12_result[0][i-1], name_12_result[1][i-1],name_12_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\3129751932.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_12_A=result_12[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\3129751932.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_12_A[result['channel']==j]['avg'].values[0])

# %%
name_13_result=[]
task=['A','B','C']
result_13=result[result['name']=='name_13']
for i in task:
    save=[]
    result_13_A=result_13[result['task']==i]
    for j in range(1,16):
        save.append(result_13_A[result['channel']==j]['avg'].values[0])
    name_13_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_13 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_13_result[0][i-1], name_13_result[1][i-1],name_13_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\450028441.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_13_A=result_13[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\450028441.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_13_A[result['channel']==j]['avg'].values[0])

# %%
name_14_result=[]
task=['A','B','C']
result_14=result[result['name']=='name_8']
for i in task:
    save=[]
    result_14_A=result_14[result['task']==i]
    for j in range(1,16):
        save.append(result_14_A[result['channel']==j]['avg'].values[0])
    name_14_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_14 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_14_result[0][i-1], name_14_result[1][i-1],name_14_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\1027038695.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_14_A=result_14[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\1027038695.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_14_A[result['channel']==j]['avg'].values[0])

# %%
name_15_result=[]
task=['A','B','C']
result_15=result[result['name']=='name_15']
for i in task:
    save=[]
    result_15_A=result_15[result['task']==i]
    for j in range(1,16):
        save.append(result_15_A[result['channel']==j]['avg'].values[0])
    name_15_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_15 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_15_result[0][i-1], name_15_result[1][i-1],name_15_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\316194745.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_15_A=result_15[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\316194745.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_15_A[result['channel']==j]['avg'].values[0])

# %%
name_16_result=[]
task=['A','B','C']
result_16=result[result['name']=='name_16']
for i in task:
    save=[]
    result_16_A=result_16[result['task']==i]
    for j in range(1,16):
        save.append(result_16_A[result['channel']==j]['avg'].values[0])
    name_16_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_16 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_16_result[0][i-1], name_16_result[1][i-1],name_16_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\3445493760.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_16_A=result_16[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\3445493760.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_16_A[result['channel']==j]['avg'].values[0])

# %%
name_17_result=[]
task=['A','B','C']
result_17=result[result['name']=='name_17']
for i in task:
    save=[]
    result_17_A=result_17[result['task']==i]
    for j in range(1,16):
        save.append(result_17_A[result['channel']==j]['avg'].values[0])
    name_17_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_8 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_17_result[0][i-1], name_17_result[1][i-1],name_17_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\2565797333.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_17_A=result_17[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\2565797333.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_17_A[result['channel']==j]['avg'].values[0])

# %%
name_19_result=[]
task=['A','B','C']
result_19=result[result['name']=='name_19']
for i in task:
    save=[]
    result_19_A=result_19[result['task']==i]
    for j in range(1,16):
        save.append(result_19_A[result['channel']==j]['avg'].values[0])
    name_19_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('name_19 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_19_result[0][i-1], name_19_result[1][i-1],name_19_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\663087667.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_19_A=result_19[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\663087667.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_19_A[result['channel']==j]['avg'].values[0])

# %%
name_k1_result=[]
task=['A','B','C']
result_k1=result[result['name']=='k1']
for i in task:
    save=[]
    result_k1_A=result_k1[result['task']==i]
    for j in range(1,16):
        save.append(result_k1_A[result['channel']==j]['avg'].values[0])
    name_k1_result.append(save)
    
x = np.arange(3)

plt.figure(figsize=(20, 30))

for i in range(1,16):
    plt.subplot(5,3,i)
    plt.title('k1 Bar plot of channel'+str(i)+" while play")
    task = ['A', 'B', 'C']
    values = [name_k1_result[0][i-1], name_k1_result[1][i-1],name_k1_result[2][i-1]]
    plt.bar(x, values)
    plt.xticks(x, task)
# Out:
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\151811660.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result_k1_A=result_k1[result['task']==i]
# C:\Users\bml05\AppData\Local\Temp\ipykernel_8124\151811660.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   save.append(result_k1_A[result['channel']==j]['avg'].values[0])
